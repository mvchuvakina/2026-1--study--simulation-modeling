# %% [markdown]
# # Базовый прогон модели SIR на сетях Петри
#
# **Цель:** Выполнить детерминированное и стохастическое моделирование
# эпидемии SIR с использованием сетей Петри.
#
# **Автор:** Чувакина Мария Владимировна
# **Дата:** 2026-04-21
#
# ## Теоретическое введение
#
# Модель SIR описывает распространение инфекционного заболевания
# в популяции. Сеть Петри содержит два перехода:
# - **infection:** S + I → I + I (скорость β)
# - **recovery:** I → R (скорость γ)
#
# ## Параметры модели (вариант 56)

# %%
using DrWatson
@quickactivate

using Random
using DataFrames, CSV, Plots

include(srcdir("SIRPetri.jl"))
using .SIRPetri

β = 0.3
γ = 0.1
tmax = 100.0

println("="^60)
println("БАЗОВЫЙ ПРОГОН МОДЕЛИ SIR")
println("="^60)
println("β = $β, γ = $γ, tmax = $tmax")
println("Начальные условия: S₀ = 990, I₀ = 10, R₀ = 0")
println()
# Out:
# ============================================================
# БАЗОВЫЙ ПРОГОН МОДЕЛИ SIR
# ============================================================
# β = 0.3, γ = 0.1, tmax = 100.0
# Начальные условия: S₀ = 990, I₀ = 10, R₀ = 0

# %% [markdown]
# ## Создание сети Петри

# %%
net, u0, states = build_sir_network(β, γ)
# Out:
# (Main.SIRPetri.PetriNet(3, 2, [-1 0; 1 -1; 0 1], [:S, :I, :R], [:infection, :recovery]), [990.0, 10.0, 0.0], [:S, :I, :R])

# %% [markdown]
# ## Детерминированная симуляция

# %%
df_det = simulate_deterministic(net, u0, (0.0, tmax), saveat = 0.5, rates = [β, γ])
CSV.write(datadir("sir_det.csv"), df_det)
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab06/project/data/sir_det.csv"

# %% [markdown]
# ## Стохастическая симуляция

# %%
Random.seed!(123)
df_stoch = simulate_stochastic(net, u0, (0.0, tmax), rates = [β, γ])
CSV.write(datadir("sir_stoch.csv"), df_stoch)
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab06/project/data/sir_stoch.csv"

# %% [markdown]
# ## Визуализация

# %%
p_det = plot_sir(df_det)
savefig(plotsdir("sir_det_dynamics.png"))

p_stoch = plot_sir(df_stoch)
savefig(plotsdir("sir_stoch_dynamics.png"))
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab06/project/plots/sir_stoch_dynamics.png"

# %% [markdown]
# ## Выводы

# %%
println("Базовый прогон завершён.")
println("Результаты сохранены в data/ и plots/")
# Out:
# Базовый прогон завершён.
# Результаты сохранены в data/ и plots/
