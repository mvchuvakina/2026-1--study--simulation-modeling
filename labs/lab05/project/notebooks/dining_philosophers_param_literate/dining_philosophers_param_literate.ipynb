# %% [markdown]
# # Параметрическое исследование: влияние числа философов
#
# **Цель:** Исследовать, как количество философов N влияет на
# возникновение deadlock в классической сети.
#
# ## Теоретическое введение
#
# В классической постановке deadlock возникает при N ≥ 2.
# При N = 1 философ может есть без проблем.
#
# ## Параметры исследования

# %%
using DrWatson
@quickactivate

using DataFrames, CSV, Plots
include(srcdir("DiningPhilosophers.jl"))
using .DiningPhilosophers

# %% [markdown]
# Сетка параметров: N от 2 до 10

# %%
N_values = 2:10
tmax = 50.0

results = []

println("="^60)
println("ПАРАМЕТРИЧЕСКОЕ ИССЛЕДОВАНИЕ")
println("Влияние количества философов N на deadlock")
println("="^60)
# Out:
# ============================================================
# ПАРАМЕТРИЧЕСКОЕ ИССЛЕДОВАНИЕ
# Влияние количества философов N на deadlock
# ============================================================

# %% [markdown]
# ## Запуск экспериментов

# %%
for N in N_values
    println("Исследование N = $N...")

    net, u0, _ = build_classical_network(N)
    df = simulate_stochastic(net, u0, tmax)
    dead = detect_deadlock(df, net)

    push!(results, (N=N, deadlock=dead))
    println("  Deadlock: $dead")
end
# Out:
# Исследование N = 2...
#   Deadlock: true
# Исследование N = 3...
#   Deadlock: true
# Исследование N = 4...
#   Deadlock: true
# Исследование N = 5...
#   Deadlock: true
# Исследование N = 6...
#   Deadlock: true
# Исследование N = 7...
#   Deadlock: true
# Исследование N = 8...
#   Deadlock: true
# Исследование N = 9...
#   Deadlock: true
# Исследование N = 10...
#   Deadlock: true

# %% [markdown]
# ## Сохранение результатов

# %%
df_results = DataFrame(results)
CSV.write(datadir("parametric_N_results.csv"), df_results)
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab05/project/data/parametric_N_results.csv"

# %% [markdown]
# ## Визуализация

# %%
plot(df_results.N, [d ? 1 : 0 for d in df_results.deadlock],
     marker=:circle, linewidth=2,
     xlabel="Количество философов N",
     ylabel="Deadlock (1=да, 0=нет)",
     title="Зависимость deadlock от количества философов")
savefig(plotsdir("parametric_N.png"))
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab05/project/plots/parametric_N.png"

# %% [markdown]
# ## Анализ результатов

# %%
println()
println("Результаты сохранены:")
println("  - data/parametric_N_results.csv")
println("  - plots/parametric_N.png")
# Out:
# Результаты сохранены:
#   - data/parametric_N_results.csv
#   - plots/parametric_N.png

# %% [markdown]
# Вывод: при N ≥ 2 deadlock возникает с вероятностью 1
