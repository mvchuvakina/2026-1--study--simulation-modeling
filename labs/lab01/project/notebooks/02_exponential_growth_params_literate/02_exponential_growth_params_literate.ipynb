# %% [markdown]
# # Параметрическое исследование экспоненциального роста
#
# ## Цель
# Изучить влияние параметра α на динамику системы.

# %%
using DrWatson
@quickactivate "project"
using DifferentialEquations
using DataFrames
using Plots
using JLD2

script_name = splitext(basename(PROGRAM_FILE))[1]
mkpath(plotsdir(script_name))
mkpath(datadir(script_name))
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab01/project/data"

# %% [markdown]
# ## Модель

# %%
function exponential_growth!(du, u, p, t)
    α = p
    du[1] = α * u[1]
end
# Out:
# exponential_growth! (generic function with 1 method)

# %% [markdown]
# ## Набор параметров

# %%
alpha_values = [0.1, 0.3, 0.5, 0.8, 1.0]
results = []

println("Параметрическое исследование:")
println(repeat("-", 40))

for α in alpha_values
    println("Вычисляем для α = $α")
    prob = ODEProblem(exponential_growth!, [1.0], (0.0, 10.0), α)
    sol = solve(prob, Tsit5(), saveat=0.1)

    final_pop = last(sol.u)[1]
    doubling = log(2) / α

    push!(results, (α=α, final_population=final_pop, doubling_time=doubling))

    println("  u(10) = $(round(final_pop, digits=2)), T₂ = $(round(doubling, digits=2))")
# Out:
# Параметрическое исследование:
# ----------------------------------------
# ParseError:
# # Error @ ]8;;file:///afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab01/project/notebooks/02_exponential_growth_params_literate/In[3]#17:90\In[3]:17:90]8;;\
#
#     println("  u(10) = $(round(final_pop, digits=2)), T₂ = $(round(doubling, digits=2))")
# #                                                                                        └ ── Expected `end`
#
# Stacktrace:
#  [1] top-level scope
#    @ In[3]:17

# %% [markdown]
# Строим график для текущего α

# %%
    plot(sol, label="α=$α", lw=2)
end  # <- ВАЖНО: закрываем цикл!
# Out:
# UndefVarError: `α` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[4]:1

# %% [markdown]
# ## Сравнительный график

# %%
plot!(xlabel="Время t", ylabel="Популяция u",
      title="Сравнение траекторий при разных α",
      legend=:topleft)
savefig(plotsdir(script_name, "comparison.png"))
# Out:
# "/afs/.dk.sci.pfu.edu.ru/home/m/v/mvchuvakina/work/study/2026-1/2026-1--study--simulation-modeling/labs/lab01/project/plots/comparison.png"

# %% [markdown]
# ## Таблица результатов

# %%
results_df = DataFrame(results)
println("\nСводная таблица:")
println(results_df)
# Out:
# Сводная таблица:
# 0×0 DataFrame

# %% [markdown]
# ## График времени удвоения

# %%
p2 = scatter(results_df.α, results_df.doubling_time,
             label="Численное решение",
             xlabel="Скорость роста α",
             ylabel="Время удвоения T₂",
             title="Зависимость времени удвоения от α",
             markersize=8, markercolor=:red)

α_range = 0.1:0.01:1.0
plot!(p2, α_range, log.(2) ./ α_range,
      label="Теория: T₂ = ln(2)/α",
      lw=2, linestyle=:dash, linecolor=:blue)
savefig(plotsdir(script_name, "doubling_time_vs_alpha.png"))
# Out:
# ArgumentError: column name "α" not found in the data frame since it has no columns
#
# Stacktrace:
#  [1] lookupname
#    @ /var/tmp/mvchuvakina/packages/DataFrames/b4w9K/src/other/index.jl:428 [inlined]
#  [2] getindex
#    @ /var/tmp/mvchuvakina/packages/DataFrames/b4w9K/src/other/index.jl:440 [inlined]
#  [3] getindex(df::DataFrame, ::typeof(!), col_ind::Symbol)
#    @ DataFrames /var/tmp/mvchuvakina/packages/DataFrames/b4w9K/src/dataframe/dataframe.jl:557
#  [4] getproperty(df::DataFrame, col_ind::Symbol)
#    @ DataFrames /var/tmp/mvchuvakina/packages/DataFrames/b4w9K/src/abstractdataframe/abstractdataframe.jl:448
#  [5] top-level scope
#    @ In[7]:1

# %% [markdown]
# ## Сохранение

# %%
@save datadir(script_name, "param_results.jld2") results_df

println("\nГотово! Результаты сохранены в data/$(script_name)")
# Out:
# Готово! Результаты сохранены в data/
